# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def LoadData(fname):
    """Loads data from an NPZ file.

    Args:
        fname: NPZ filename.

    Returns:
        data: Tuple {inputs, target}_{train, valid, test}.
              Row-major, outer axis to be the number of observations.
    """
    npzfile = np.load(fname)

    inputs_train = npzfile['inputs_train'].T / 255.0
    inputs_valid = npzfile['inputs_valid'].T / 255.0
    inputs_test = npzfile['inputs_test'].T / 255.0
    target_train = npzfile['target_train'].tolist()
    target_valid = npzfile['target_valid'].tolist()
    target_test = npzfile['target_test'].tolist()

    num_class = max(target_train + target_valid + target_test) + 1
    target_train_1hot = np.zeros([num_class, len(target_train)])
    target_valid_1hot = np.zeros([num_class, len(target_valid)])
    target_test_1hot = np.zeros([num_class, len(target_test)])

    for ii, xx in enumerate(target_train):
        target_train_1hot[xx, ii] = 1.0

    for ii, xx in enumerate(target_valid):
        target_valid_1hot[xx, ii] = 1.0

    for ii, xx in enumerate(target_test):
        target_test_1hot[xx, ii] = 1.0

    inputs_train = inputs_train.T
    inputs_valid = inputs_valid.T
    inputs_test = inputs_test.T
    target_train_1hot = target_train_1hot.T
    target_valid_1hot = target_valid_1hot.T
    target_test_1hot = target_test_1hot.T
    return inputs_train, inputs_valid, inputs_test, target_train_1hot, target_valid_1hot, target_test_1hot

# %%
# explore data:
npzfile = np.load('toronto_face.npz')
target_train = npzfile['target_train'].tolist()
print 'num of trainign image: ',len(target_train)
print 'max target value: ',max(target_train)
print "min target value: ",min(target_train)
counter = []
for i in range(7):
    counter.append( target_train.count(i) )
print counter
classes = ['Anger','Disgust','Fear','Happy','Sad','Suprised','Neutral']
plt.bar(range(7),counter)
plt.xlabel('class')
plt.ylabel('example count')
# Out:
# num of trainign image:  3374
# max target value:  6
# min target value:  0
# [355, 372, 339, 611, 356, 378, 963]

# %%
inputs_train, inputs_valid, inputs_test, target_train, target_valid, \
    target_test = LoadData('toronto_face.npz')
print inputs_train.shape
print inputs_valid.shape
print inputs_test.shape
print target_train.shape
print target_valid.shape
print target_test.shape
# Out:
# (3374, 2304)
# (419, 2304)
# (385, 2304)
# (3374, 7)
# (419, 7)
# (385, 7)

# %%
import tensorflow as tf
sess = tf.InteractiveSession()

# %%
x = tf.placeholder(tf.float32, shape=[None, 2304])
y_ = tf.placeholder(tf.float32, shape=[None, 7])

# %%
def weight_variable(shape):
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial)

def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

def conv2d(x, W):
  return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
  return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

# %%
x_image = tf.reshape(x, [-1,48,48,1])

W_conv1 = weight_variable([8, 8, 1, 32])
b_conv1 = bias_variable([32])
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

W_conv2 = weight_variable([5, 5, 32, 48])
b_conv2 = bias_variable([48])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

W_conv3 = weight_variable([5, 5, 48, 64])
b_conv3 = bias_variable([64])
h_conv3 = tf.nn.relu(conv2d(h_pool2, W_conv3) + b_conv3)
h_pool3 = max_pool_2x2(h_conv3)

W_fc1 = weight_variable([6 * 6 * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool3_flat = tf.reshape(h_pool3, [-1, 6*6*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat, W_fc1) + b_fc1)

keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

W_fc2 = weight_variable([1024, 7])
b_fc2 = bias_variable([7])

y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

# %%
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(y_conv, y_))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
sess.run(tf.initialize_all_variables())


num_of_epoch = 100
batch_size = 241
num_of_data = inputs_train.shape[0]
iterations = num_of_data/batch_size*num_of_epoch

# list of number of epoch, accuracy and cross-entropy for training and validation
epoch_log = []
train_acc_log = []
val_acc_log = []
train_ce_log = []
val_ce_log = []

batch_num = 0

for iteration in range(iterations):
        
    inputs_batch = inputs_train[batch_num*batch_size : (batch_num+1)*batch_size]
    target_batch = target_train[batch_num*batch_size : (batch_num+1)*batch_size]
    
    if batch_num >= num_of_data / batch_size - 1 :
        batch_num = 0
    else:
        batch_num = batch_num + 1
        
    
    if (iteration+1) % (num_of_data / batch_size ) == 0:     # when finish each epoch:     

        train_accuracy = accuracy.eval(feed_dict={
        x:inputs_batch, y_: target_batch, keep_prob: 1.0})
        print("epoch %d, training accuracy %g"%((iteration+1)/(num_of_data/batch_size), train_accuracy))
        epoch_log.append((iteration+1)/(num_of_data/batch_size))
        train_acc_log.append(train_accuracy)
        
        train_ce = cross_entropy.eval(feed_dict={
        x:inputs_batch, y_: target_batch, keep_prob: 1.0})
        train_ce_log.append(train_ce)
        
        val_accuracy = accuracy.eval(feed_dict={
        x:inputs_valid, y_: target_valid, keep_prob: 1.0})
        print("epoch %d, validation accuracy %g"%((iteration+1)/(num_of_data/batch_size), val_accuracy))
        val_acc_log.append(val_accuracy)
        
        val_ce = cross_entropy.eval(feed_dict={
        x:inputs_valid, y_: target_valid, keep_prob: 1.0})
        val_ce_log.append(val_ce)
        

    train_step.run(feed_dict={x: inputs_batch, y_: target_batch, keep_prob: 0.5})

print("test accuracy %g"%accuracy.eval(feed_dict={
    x: inputs_test, y_: target_test, keep_prob: 1.0}))
# Out:
# epoch 1, training accuracy 0.290456
# epoch 1, validation accuracy 0.279236
# epoch 2, training accuracy 0.290456
# epoch 2, validation accuracy 0.279236
# epoch 3, training accuracy 0.360996
# epoch 3, validation accuracy 0.338902
# epoch 4, training accuracy 0.419087
# epoch 4, validation accuracy 0.405728
# epoch 5, training accuracy 0.460581
# epoch 5, validation accuracy 0.443914
# epoch 6, training accuracy 0.502075
# epoch 6, validation accuracy 0.51074
# epoch 7, training accuracy 0.53112
# epoch 7, validation accuracy 0.546539
# epoch 8, training accuracy 0.59751
# epoch 8, validation accuracy 0.548926
# epoch 9, training accuracy 0.639004
# epoch 9, validation accuracy 0.572792
# epoch 10, training accuracy 0.643154
# epoch 10, validation accuracy 0.584726
# epoch 11, training accuracy 0.643154
# epoch 11, validation accuracy 0.596659
# epoch 12, training accuracy 0.647303
# epoch 12, validation accuracy 0.608592
# epoch 13, training accuracy 0.659751
# epoch 13, validation accuracy 0.608592
# epoch 14, training accuracy 0.688797
# epoch 14, validation accuracy 0.618138
# epoch 15, training accuracy 0.680498
# epoch 15, validation accuracy 0.618138
# epoch 16, training accuracy 0.697095
# epoch 16, validation accuracy 0.642005
# epoch 17, training accuracy 0.721992
# epoch 17, validation accuracy 0.653938
# epoch 18, training accuracy 0.721992
# epoch 18, validation accuracy 0.658711
# epoch 19, training accuracy 0.738589
# epoch 19, validation accuracy 0.682578
# epoch 20, training accuracy 0.738589
# epoch 20, validation accuracy 0.675418
# epoch 21, training accuracy 0.717842
# epoch 21, validation accuracy 0.675418
# epoch 22, training accuracy 0.763485
# epoch 22, validation accuracy 0.684964
# epoch 23, training accuracy 0.763485
# epoch 23, validation accuracy 0.689737
# epoch 24, training accuracy 0.771784
# epoch 24, validation accuracy 0.696897
# epoch 25, training accuracy 0.763485
# epoch 25, validation accuracy 0.704057
# epoch 26, training accuracy 0.763485
# epoch 26, validation accuracy 0.689737
# epoch 27, training accuracy 0.784232
# epoch 27, validation accuracy 0.704057
# epoch 28, training accuracy 0.792531
# epoch 28, validation accuracy 0.711217
# epoch 29, training accuracy 0.809129
# epoch 29, validation accuracy 0.711217
# epoch 30, training accuracy 0.792531
# epoch 30, validation accuracy 0.718377
# epoch 31, training accuracy 0.80083
# epoch 31, validation accuracy 0.725537
# epoch 32, training accuracy 0.809129
# epoch 32, validation accuracy 0.735084
# epoch 33, training accuracy 0.804979
# epoch 33, validation accuracy 0.718377
# epoch 34, training accuracy 0.821577
# epoch 34, validation accuracy 0.739857
# epoch 35, training accuracy 0.842324
# epoch 35, validation accuracy 0.74463
# epoch 36, training accuracy 0.829876
# epoch 36, validation accuracy 0.754177
# epoch 37, training accuracy 0.825726
# epoch 37, validation accuracy 0.739857
# epoch 38, training accuracy 0.842324
# epoch 38, validation accuracy 0.74463
# epoch 39, training accuracy 0.854772
# epoch 39, validation accuracy 0.749403
# epoch 40, training accuracy 0.850622
# epoch 40, validation accuracy 0.754177
# epoch 41, training accuracy 0.825726
# epoch 41, validation accuracy 0.75179
# epoch 42, training accuracy 0.846473
# epoch 42, validation accuracy 0.74463
# epoch 43, training accuracy 0.86722
# epoch 43, validation accuracy 0.749403
# epoch 44, training accuracy 0.879668
# epoch 44, validation accuracy 0.75895
# epoch 45, training accuracy 0.879668
# epoch 45, validation accuracy 0.74463
# epoch 46, training accuracy 0.883817
# epoch 46, validation accuracy 0.74463
# epoch 47, training accuracy 0.879668
# epoch 47, validation accuracy 0.754177
# epoch 48, training accuracy 0.887967
# epoch 48, validation accuracy 0.749403
# epoch 49, training accuracy 0.887967
# epoch 49, validation accuracy 0.747017
# epoch 50, training accuracy 0.892116
# epoch 50, validation accuracy 0.749403
# epoch 51, training accuracy 0.896266
# epoch 51, validation accuracy 0.761337
# epoch 52, training accuracy 0.896266
# epoch 52, validation accuracy 0.747017
# epoch 53, training accuracy 0.900415
# epoch 53, validation accuracy 0.74463
# epoch 54, training accuracy 0.917012
# epoch 54, validation accuracy 0.75895
# epoch 55, training accuracy 0.908714
# epoch 55, validation accuracy 0.75895
# epoch 56, training accuracy 0.904564
# epoch 56, validation accuracy 0.76611
# epoch 57, training accuracy 0.912863
# epoch 57, validation accuracy 0.76611
# epoch 58, training accuracy 0.912863
# epoch 58, validation accuracy 0.770883
# epoch 59, training accuracy 0.929461
# epoch 59, validation accuracy 0.763723
# epoch 60, training accuracy 0.925311
# epoch 60, validation accuracy 0.76611
# epoch 61, training accuracy 0.925311
# epoch 61, validation accuracy 0.76611
# epoch 62, training accuracy 0.937759
# epoch 62, validation accuracy 0.747017
# epoch 63, training accuracy 0.925311
# epoch 63, validation accuracy 0.761337
# epoch 64, training accuracy 0.929461
# epoch 64, validation accuracy 0.749403
# epoch 65, training accuracy 0.929461
# epoch 65, validation accuracy 0.77327
# epoch 66, training accuracy 0.937759
# epoch 66, validation accuracy 0.763723
# epoch 67, training accuracy 0.93361
# epoch 67, validation accuracy 0.770883
# epoch 68, training accuracy 0.93361
# epoch 68, validation accuracy 0.76611
# epoch 69, training accuracy 0.93361
# epoch 69, validation accuracy 0.77327
# epoch 70, training accuracy 0.937759
# epoch 70, validation accuracy 0.768496
# epoch 71, training accuracy 0.93361
# epoch 71, validation accuracy 0.770883
# epoch 72, training accuracy 0.941909
# epoch 72, validation accuracy 0.768496
# epoch 73, training accuracy 0.954357
# epoch 73, validation accuracy 0.76611
# epoch 74, training accuracy 0.954357
# epoch 74, validation accuracy 0.761337
# epoch 75, training accuracy 0.954357
# epoch 75, validation accuracy 0.770883
# epoch 76, training accuracy 0.941909
# epoch 76, validation accuracy 0.761337
# epoch 77, training accuracy 0.941909
# epoch 77, validation accuracy 0.76611
# epoch 78, training accuracy 0.950207
# epoch 78, validation accuracy 0.770883
# epoch 79, training accuracy 0.958506
# epoch 79, validation accuracy 0.761337
# epoch 80, training accuracy 0.946058
# epoch 80, validation accuracy 0.75895
# epoch 81, training accuracy 0.958506
# epoch 81, validation accuracy 0.775656
# epoch 82, training accuracy 0.954357
# epoch 82, validation accuracy 0.770883
# epoch 83, training accuracy 0.954357
# epoch 83, validation accuracy 0.763723
# epoch 84, training accuracy 0.954357
# epoch 84, validation accuracy 0.77327
# epoch 85, training accuracy 0.954357
# epoch 85, validation accuracy 0.768496
# epoch 86, training accuracy 0.962656
# epoch 86, validation accuracy 0.770883
# epoch 87, training accuracy 0.954357
# epoch 87, validation accuracy 0.756563
# epoch 88, training accuracy 0.966805
# epoch 88, validation accuracy 0.756563
# epoch 89, training accuracy 0.962656
# epoch 89, validation accuracy 0.763723
# epoch 90, training accuracy 0.966805
# epoch 90, validation accuracy 0.782816
# epoch 91, training accuracy 0.966805
# epoch 91, validation accuracy 0.761337
# epoch 92, training accuracy 0.975104
# epoch 92, validation accuracy 0.782816
# epoch 93, training accuracy 0.975104
# epoch 93, validation accuracy 0.775656
# epoch 94, training accuracy 0.966805
# epoch 94, validation accuracy 0.770883
# epoch 95, training accuracy 0.966805
# epoch 95, validation accuracy 0.77327
# epoch 96, training accuracy 0.970954
# epoch 96, validation accuracy 0.770883
# epoch 97, training accuracy 0.970954
# epoch 97, validation accuracy 0.78043
# epoch 98, training accuracy 0.970954
# epoch 98, validation accuracy 0.77327
# epoch 99, training accuracy 0.970954
# epoch 99, validation accuracy 0.775656
# epoch 100, training accuracy 0.970954
# epoch 100, validation accuracy 0.76611
# test accuracy 0.815584

# %%
plt.plot(epoch_log, train_acc_log, label = 'Training')
plt.plot(epoch_log, val_acc_log, label = 'Validation')
legend = plt.legend(loc='lower right', fontsize='large')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid()

# %%
plt.plot(epoch_log, train_ce_log, label = 'Training')
plt.plot(epoch_log, val_ce_log, label = 'Validation')
legend = plt.legend(loc='lower right', fontsize='large')
plt.xlabel('Epoch')
plt.ylabel('Cross-Entropy')
plt.grid()

# %%
# show a sample prediction from test set
softmax = tf.nn.softmax(y_conv, dim=-1, name=None)
image = inputs_test[0].reshape(-1,2304)

print "probability for each class:" 
probability = softmax.eval(feed_dict={x: image, keep_prob: 1.0},session=sess)
probability = probability.round(3)
print probability
print "correct label(one-hot):"
print target_test[0]
image = image.reshape(48,48)
plt.figure()
plt.imshow(image,cmap='gray')
# Out:
# probability for each class:
# [[ 0.     0.002  0.     0.963  0.     0.     0.035]]
# correct label(one-hot):
# [ 0.  0.  0.  1.  0.  0.  0.]
# probability for each class:
# [[ 0.004       0.001       0.67000002  0.002       0.01        0.21699999
#    0.096     ]]
# correct label(one-hot):
# [ 0.  0.  1.  0.  0.  0.  0.]

# %%
image = inputs_test[200].reshape(-1,2304)
print "probability for each class:" 
probability = softmax.eval(feed_dict={x: image, keep_prob: 1.0},session=sess)
probability = probability.round(3)
print probability
print "correct label(one-hot):"
print target_test[200]
image = image.reshape(48,48)
plt.figure()
plt.imshow(image,cmap='gray')
